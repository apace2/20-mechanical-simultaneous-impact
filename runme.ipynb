# %%
# %matplotlib inline

# %% [markdown]
# # Biped model
#
# ## Generate the data

# %%
# %run -m biped.run_biped
# Out:
# Data already exists in file : /Users/apace2/PhD/Code/20-systems-siad/biped/.RigidBiped_perturb.npz
# Not regenerating the data
# Data already exists in file : /Users/apace2/PhD/Code/20-systems-siad/biped/.DecoupledBiped_perturb.npz
# Not regenerating the data
# Data already exists in file : /Users/apace2/PhD/Code/20-systems-siad/biped/.PCrBiped_perturb.npz
# Not regenerating the data
#
#
#
# Generating variational equation solutions
# Data already exists in file : /Users/apace2/PhD/Code/20-systems-siad/biped/.PCrBiped_var.npz
# Not regenerating the data
# Data already exists in file : /Users/apace2/PhD/Code/20-systems-siad/biped/.DecoupledBiped_var.npz
# Not regenerating the data

# %% [markdown]
# ## Generate plots

# %%
# %run -m biped.plot_biped

# %% [markdown]
# # Double Pendulum model

# %% [markdown]
# ## System image

# %%
# %run -m pendulum.DoublePendulum

# %% [markdown]
# ## Generate a nonsmooth controller and plot the result

# %%
# %run -m pendulum.nonsmooth_controller
# Out:
# Using nonsmooth controller data from file: /Users/apace2/PhD/Code/20-systems-siad/pendulum/.nonsmooth_control.npz
# To regenerate data, delete data file or use flag '--no-saved'
